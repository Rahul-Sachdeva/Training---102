# %% [markdown]
# <a href="https://colab.research.google.com/github/Rahul-Sachdeva/Training---102-Daily-Dairy/blob/main/PythonExercise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1. Write a program that checks if a number is odd or even.
x = int(input("Enter the Number: "))
print("x is Even: ", x%2==0)

# 2. Write a program that finds the largest among three numbers.
x = int(input("Enter the Number: "))
y = int(input("Enter the Number: "))
z = int(input("Enter the Number: "))
print(max(x,y,z))

# 3. Write a program to check if a given year is a leap year.
year = int(input("Enter the Number: "))
if (year % 4 == 0 and year % 100 != 0) or year % 400 == 0:
    print("Leap Year")
else:
    print("Not Leap Year")


# 4. Write a program that calculates the grade of a student based on their marks.
marks = int(input("Enter marks: "))
if marks >= 90:
    grade = 'A'
elif marks >= 80:
    grade = 'B'
elif marks >= 70:
    grade = 'C'
elif marks >= 60:
    grade = 'D'
else:
    grade = 'F'
print(f"Grade: {grade}")

# 5. Write a program that checks if a character is a vowel or consonant.
char = input("Enter a character: ").lower()
if char in 'aeiou':
    print("Vowel")
else:
    print("Consonant")

# 6. Write a program that checks if a number is positive, negative, or zero.
num = float(input("Enter a number: "))
if num > 0:
    print("Positive")
elif num < 0:
    print("Negative")
else:
    print("Zero")

# 7. Write a program that checks if a number is divisible by 5 and 11.
num = int(input("Enter a number: "))
if num % 5 == 0 and num % 11 == 0:
    print("Divisible by both 5 and 11")
else:
    print("Not divisible by both 5 and 11")

# 8. Write a program to check if three given lengths can form a triangle.
a = float(input("Enter length 1: "))
b = float(input("Enter length 2: "))
c = float(input("Enter length 3: "))
if a + b > c and a + c > b and b + c > a:
    print("Can form a triangle")
else:
    print("Cannot form a triangle")

# 9. Write a program to check if a number is within a specific range.
num = int(input("Enter a number: "))
low = int(input("Enter lower range: "))
high = int(input("Enter upper range: "))
if low <= num <= high:
    print("Within range")
else:
    print("Out of range")

# 10. Write a program that prints the number of days in a given month.
month = int(input("Enter month number (1-12): "))
if month in [1, 3, 5, 7, 8, 10, 12]:
    days = 31
elif month in [4, 6, 9, 11]:
    days = 30
elif month == 2:
    year = int(input("Enter year: "))
    days = 29 if (year % 4 == 0 and year % 100 != 0) or (year % 400 == 0) else 28
else:
    days = "Invalid month"
print(f"Days: {days}")

# 11. Write a program that prints numbers from 1 to 100 using a loop.
for i in range(1, 101):
    print(i, end=" ")

# 12. Write a program to find the sum of the first N natural numbers.
N = int(input("Enter N: "))
sum_n = N * (N + 1) // 2
print(f"Sum: {sum_n}")

# 13. Write a program to calculate the factorial of a number.
n = int(input("Enter a number: "))
factorial = 1
for i in range(1, n + 1):
    factorial *= i
print(f"Factorial: {factorial}")

# 14. Write a program to generate the Fibonacci sequence up to N terms.
N = int(input("Enter N: "))
a, b = 0, 1
for _ in range(N):
    print(a, end=" ")
    a, b = b, a + b

# 15. Write a program that checks if a number is prime.
num = int(input("Enter a number: "))
if num > 1:
    for i in range(2, int(num ** 0.5) + 1):
        if num % i == 0:
            print("Not Prime")
            break
    else:
        print("Prime")
else:
    print("Not Prime")

# 16. Write a program to print the multiplication table of a given number.
num = int(input("Enter a number: "))
for i in range(1, 11):
    print(f"{num} x {i} = {num * i}")

# 17. Write a program to reverse a given number.
num = int(input("Enter a number: "))
reversed_num = 0
while num > 0:
    reversed_num = reversed_num * 10 + num % 10
    num //= 10
print(f"Reversed Number: {reversed_num}")

# 18. Write a program to count the number of digits in a given number.
num = int(input("Enter a number: "))
print(f"Number of digits: {len(str(num))}")

# 19. Write a program to find the sum of the digits of a number.
num = int(input("Enter a number: "))
sum_digits = sum(int(digit) for digit in str(num))
print(f"Sum of digits: {sum_digits}")

# 20. Write a program to check if a number is an Armstrong number.
num = int(input("Enter a number: "))
n = len(str(num))
sum_digits = sum(int(digit) ** n for digit in str(num))
if sum_digits == num:
    print("Armstrong number")
else:
    print("Not an Armstrong number")

# 21. Write a program to find the sum of elements in a list.
lst = list(map(int, input("Enter elements separated by space: ").split()))
print(f"Sum: {sum(lst)}")

# 22. Write a program to find the maximum and minimum elements in a list.
lst = list(map(int, input("Enter elements separated by space: ").split()))
print(f"Max: {max(lst)}, Min: {min(lst)}")

# 23. Write a program to find the average of elements in a list.
lst = list(map(int, input("Enter elements separated by space: ").split()))
print(f"Average: {sum(lst) / len(lst)}")

# 24. Write a program to reverse a given string.
s = input("Enter a string: ")
print(f"Reversed string: {s[::-1]}")

# 25. Write a program to check if a string is a palindrome.
s = input("Enter a string: ")
if s == s[::-1]:
    print("Palindrome")
else:
    print("Not a palindrome")

# 26. Write a program to count the number of vowels in a given string.
s = input("Enter a string: ").lower()
vowels = 'aeiou'
count = sum(1 for char in s if char in vowels)
print(f"Number of vowels: {count}")

# 27. Write a program to swap keys and values in a dictionary.
d = {'a': 1, 'b': 2, 'c': 3}
swapped = {v: k for k, v in d.items()}
print(swapped)

# 28. Write a program to merge two dictionaries.
d1 = {'a': 1, 'b': 2}
d2 = {'b': 3, 'c': 4}
merged = {**d1, **d2}
print(merged)

# 29. Write a program to perform union, intersection, and difference operations on sets.
set1 = {1, 2, 3}
set2 = {2, 3, 4}
print(f"Union: {set1 | set2}")
print(f"Intersection: {set1 & set2}")
print(f"Difference: {set1 - set2}")

# 30. Write a program to perform operations (like sum, min, max) on a tuple.
t = (1, 2, 3, 4, 5)
print(f"Sum: {sum(t)}, Min: {min(t)}, Max: {max(t)}")

# 31. Write a program to simulate a basic login authentication system.
username = "user"
password = "pass"
input_user = input("Enter username: ")
input_pass = input("Enter password: ")
if input_user == username and input_pass == password:
    print("Login successful")
else:
    print("Login failed")

# 32. Write a program to find the roots of a quadratic equation.
import cmath
a, b, c = map(float, input("Enter coefficients a, b, c: ").split())
d1 = b**2 - 4*a*c
if d1>0:
  d = cmath.sqrt(d1)
  root1 = (-b + d) / (2*a)
  root2 = (-b - d) / (2*a)
  print(f"Roots: {root1}, {root2}")
else:
  print("No Real Roots Exists")

# 33. Write a program to categorize grades into A, B, C, D, or F.
marks = int(input("Enter marks: "))
if marks >= 90:
    grade = 'A'
elif marks >= 80:
    grade = 'B'
elif marks >= 70:
    grade = 'C'
elif marks >= 60:
    grade = 'D'
else:
    grade = 'F'
print(f"Grade: {grade}")

# 34. Write a program to simulate a simple calculator using if-elif-else.
def calculator():
    num1 = float(input("Enter first number: "))
    operator = input("Enter operator (+, -, *, /): ")
    num2 = float(input("Enter second number: "))

    if operator == '+':
        print("Result:", num1 + num2)
    elif operator == '-':
        print("Result:", num1 - num2)
    elif operator == '*':
        print("Result:", num1 * num2)
    elif operator == '/':
        if num2 != 0:
            print("Result:", num1 / num2)
        else:
            print("Cannot divide by zero!")
    else:
        print("Invalid operator!")

calculator()

# 35. Write a program to calculate the Body Mass Index (BMI) and categorize it.
def calculate_bmi():
    weight = float(input("Enter weight in kg: "))
    height = float(input("Enter height in meters: "))
    bmi = weight / (height ** 2)
    print(f"BMI: {bmi:.2f}")

    if bmi < 18.5:
        print("Underweight")
    elif 18.5 <= bmi < 24.9:
        print("Normal weight")
    elif 25 <= bmi < 29.9:
        print("Overweight")
    else:
        print("Obesity")

calculate_bmi()

# 36. Write a program to determine the day of the week given a date.
import datetime

def find_day_of_week():
    date_str = input("Enter the date (YYYY-MM-DD): ")
    year, month, day = map(int, date_str.split('-'))
    date = datetime.date(year, month, day)
    print("Day of the week:", date.strftime("%A"))

find_day_of_week()

# 37. Write a program to check if a character is uppercase, lowercase, or a digit.
def check_character():
    char = input("Enter a character: ")

    if char.isupper():
        print("Uppercase")
    elif char.islower():
        print("Lowercase")
    elif char.isdigit():
        print("Digit")
    else:
        print("Special character")

check_character()

# 38. Write a program to simulate a traffic light using conditional statements.
def traffic_light():
    light = input("Enter traffic light color (red, yellow, green): ").lower()

    if light == 'red':
        print("Stop")
    elif light == 'yellow':
        print("Slow down")
    elif light == 'green':
        print("Go")
    else:
        print("Invalid color")

traffic_light()

# 39. Write a program to convert a month name to its corresponding number.
def month_to_number():
    month = input("Enter the month name: ").capitalize()
    months = ["January", "February", "March", "April", "May", "June",
              "July", "August", "September", "October", "November", "December"]

    if month in months:
        print("Month number:", months.index(month) + 1)
    else:
        print("Invalid month name")

month_to_number()

# 40. Write a program to check the strength of a password.
def check_password_strength():
    import re
    password = input("Enter password: ")
    strength = "Weak"

    if len(password) >= 8:
        if re.search("[a-z]", password) and re.search("[A-Z]", password) and re.search("[0-9]", password) and re.search("[@#$%^&+=]", password):
            strength = "Strong"
        elif re.search("[a-zA-Z]", password) and re.search("[0-9]", password):
            strength = "Moderate"

    print("Password strength:", strength)

check_password_strength()

# 41. Write a program to print a right triangle pattern using loops.
def right_triangle_pattern():
    rows = int(input("Enter number of rows: "))
    for i in range(1, rows + 1):
        print('*' * i)

right_triangle_pattern()

# 42. Write a program to print an inverted triangle pattern using loops.
def inverted_triangle_pattern():
    rows = int(input("Enter number of rows: "))
    for i in range(rows, 0, -1):
        print('*' * i)

inverted_triangle_pattern()

# 43. Write a program to print a diamond shape pattern using loops.
def diamond_pattern():
    rows = int(input("Enter number of rows: "))
    for i in range(1, rows + 1):
        print(' ' * (rows - i) + '*' * (2 * i - 1))
    for i in range(rows - 1, 0, -1):
        print(' ' * (rows - i) + '*' * (2 * i - 1))

diamond_pattern()

# 44. Write a program to find all prime numbers within a given range.
def find_primes(start, end):
    primes = []
    for num in range(start, end + 1):
        if num > 1:
            for i in range(2, int(num ** 2) + 1):
                if num % i == 0:
                    break
            else:
                primes.append(num)
    return primes

start = int(input("Enter start of range: "))
end = int(input("Enter end of range: "))
print("Prime numbers:", find_primes(start, end))

# 45. Write a program to find the sum of even and odd numbers separately in a range.
def sum_even_odd(start, end):
    even_sum = sum(num for num in range(start, end + 1) if num % 2 == 0)
    odd_sum = sum(num for num in range(start, end + 1) if num % 2 != 0)
    return even_sum, odd_sum

start = int(input("Enter start of range: "))
end = int(input("Enter end of range: "))
even_sum, odd_sum = sum_even_odd(start, end)
print(f"Sum of even numbers: {even_sum}")
print(f"Sum of odd numbers: {odd_sum}")

# 46. Write a program to find the greatest common divisor (GCD) of two numbers.
def gcd(a, b):
    while b:
        a, b = b, a % b
    return a

a = int(input("Enter first number: "))
b = int(input("Enter second number: "))
print("GCD:", gcd(a, b))

# 47. Write a program to find the least common multiple (LCM) of two numbers.
def lcm(a, b):
    def gcd(x, y):
        while y:
            x, y = y, x % y
        return x
    return abs(a * b) // gcd(a, b)

a = int(input("Enter first number: "))
b = int(input("Enter second number: "))
print("LCM:", lcm(a, b))

# 48. Write a program to print a hollow square pattern using loops.
def hollow_square(n):
    for i in range(n):
        if i == 0 or i == n-1:
            print('*' * n)
        else:
            print('*' + ' ' * (n-2) + '*')

n = int(input("Enter the size of square: "))
hollow_square(n)

# 49. Write a program to print Floyd’s triangle.
def floyds_triangle(n):
    num = 1
    for i in range(1, n + 1):
        for j in range(1, i + 1):
            print(num, end=' ')
            num += 1
        print()

n = int(input("Enter number of rows: "))
floyds_triangle(n)

# 50. Write a program to count the number of prime numbers up to a given number N.
def count_primes(n):
    count = 0
    for num in range(2, n + 1):
        for i in range(2, int(num ** 2) + 1):
            if num % i == 0:
                break
        else:
            count += 1
    return count

n = int(input("Enter the number: "))
print("Number of primes:", count_primes(n))

# 51. Write a program to remove duplicates from a list.
def remove_duplicates(lst):
    return list(set(lst))

lst = list(map(int, input("Enter list elements: ").split()))
print("List after removing duplicates:",remove_duplicates(lst))

# 52. Write a program to find the intersection of two lists.
def list_intersection():
    list1 = list(map(int, input("Enter elements of first list separated by space: ").split()))
    list2 = list(map(int, input("Enter elements of second list separated by space: ").split()))
    intersection = list(set(list1) & set(list2))
    print("Intersection:", intersection)

list_intersection()

# 53. Write a program to create a list of squares of numbers using list comprehension.
def list_of_squares():
    n = int(input("Enter the number of elements: "))
    squares = [i**2 for i in range(1, n + 1)]
    print("List of squares:", squares)

list_of_squares()

# 54. Write a program to count the number of words in a string.
def word_count():
    string = input("Enter a string: ")
    words = string.split()
    print("Number of words:", len(words))

word_count()

# 55. Write a program to capitalize the first letter of each word in a string.
def capitalize_words():
    string = input("Enter a string: ")
    capitalized_string = string.title()
    print("Capitalized string:", capitalized_string)

capitalize_words()

# 56. Write a program to sort a dictionary by its values.
def sort_dict_by_values():
    n = int(input("Enter number of dictionary elements: "))
    d = {}
    for _ in range(n):
        key = input("Enter key: ")
        value = int(input("Enter value: "))
        d[key] = value
    sorted_dict = dict(sorted(d.items(), key=lambda item: item[1]))
    print("Sorted dictionary:", sorted_dict)

sort_dict_by_values()

# 57. Write a program to sort a list of tuples based on the second element.
def sort_tuples_by_second():
    n = int(input("Enter number of tuples: "))
    tuples = []
    for _ in range(n):
        a, b = map(int, input("Enter a tuple: ").split())
        tuples.append((a, b))
    sorted_tuples = sorted(tuples, key=lambda x: x[1])
    print("Sorted tuples:", sorted_tuples)

sort_tuples_by_second()

# 58. Write a program to count the frequency of each character in a string.
def char_frequency():
    string = input("Enter a string: ")
    frequency = {}
    for char in string:
        frequency[char] = frequency.get(char, 0) + 1
    print("Character frequency:", frequency)

char_frequency()

# 59. Write a program to merge two lists and sort the result.
def merge_and_sort_lists():
    list1 = list(map(int, input("Enter elements of first list separated by space: ").split()))
    list2 = list(map(int, input("Enter elements of second list separated by space: ").split()))
    merged_list = sorted(list1 + list2)
    print("Merged and sorted list:", merged_list)

merge_and_sort_lists()

# 60. Write a program to merge two dictionaries and update values of common keys.
def merge_dicts():
    dict1 = {"a": 1, "b": 2, "c": 3}
    dict2 = {"b": 3, "c": 4, "d": 5}
    merged_dict = {**dict1, **dict2}
    print(merged_dict)
    for key in dict1:
        if key in dict2:
            merged_dict[key] = dict1[key] + dict2[key]
    print("Merged dictionary:", merged_dict)

merge_dicts()

# 61. Write a program to convert temperature from Celsius to Fahrenheit and vice versa.
def convert_temperature():
    choice = input("Convert from (C)elsius or (F)ahrenheit? ").upper()
    if choice == "C":
        celsius = float(input("Enter temperature in Celsius: "))
        fahrenheit = (celsius * 9/5) + 32
        print(f"{celsius}°C is {fahrenheit}°F")
    elif choice == "F":
        fahrenheit = float(input("Enter temperature in Fahrenheit: "))
        celsius = (fahrenheit - 32) * 5/9
        print(f"{fahrenheit}°F is {celsius}°C")
    else:
        print("Invalid choice")

convert_temperature()

# 62. Write a program to calculate simple interest.
def simple_interest():
    principal = float(input("Enter the principal amount: "))
    rate = float(input("Enter the rate of interest: "))
    time = float(input("Enter the time (years): "))
    interest = (principal * rate * time) / 100
    print(f"Simple interest is: {interest}")

simple_interest()

# 63. Write a program to calculate compound interest.
def compound_interest():
    principal = float(input("Enter the principal amount: "))
    rate = float(input("Enter the annual interest rate (in %): "))
    time = float(input("Enter the time (years): "))
    n = int(input("Enter the number of times interest is compounded per year: "))
    amount = principal * (1 + (rate / 100) / n) ** (n * time)
    interest = amount - principal
    print(f"Compound interest is: {interest}")

compound_interest()

# 64. Write a program to calculate electricity bill based on usage.
def electricity_bill():
    units = float(input("Enter number of units consumed: "))
    if units <= 100:
        bill = units * 1.5
    elif units <= 200:
        bill = 100 * 1.5 + (units - 100) * 2.5
    elif units <= 300:
        bill = 100 * 1.5 + 100 * 2.5 + (units - 200) * 4.0
    else:
        bill = 100 * 1.5 + 100 * 2.5 + 100 * 4.0 + (units - 300) * 6.0
    print(f"Electricity bill is: ${bill}")

electricity_bill()

# 65. Write a program to calculate the discount on a purchase based on amount.
def calculate_discount():
    amount = float(input("Enter purchase amount: "))
    if amount < 100:
        discount = 0
    elif amount <= 500:
        discount = amount * 0.1
    else:
        discount = amount * 0.2
    print(f"Discount is: ${discount}")
    print(f"Amount after discount: ${amount - discount}")

calculate_discount()

# 66. Write a program to convert currency from one unit to another.
def currency_converter():
    amount = float(input("Enter amount: "))
    from_currency = input("Enter from currency (USD, EUR, INR): ").upper()
    to_currency = input("Enter to currency (USD, EUR, INR): ").upper()
    conversion_rates = {
        "USD": {"EUR": 0.85, "INR": 74.0},
        "EUR": {"USD": 1.18, "INR": 87.0},
        "INR": {"USD": 0.013, "EUR": 0.011}
    }

    if from_currency == to_currency:
        print(f"Converted amount: {amount} {to_currency}")
    else:
        converted_amount = amount * conversion_rates[from_currency][to_currency]
        print(f"Converted amount: {converted_amount} {to_currency}")

currency_converter()

# 67. Write a program to calculate speeding fines based on speed limits.
def calculate_speeding_fine():
    speed = int(input("Enter the speed of the vehicle: "))
    speed_limit = int(input("Enter the speed limit: "))
    if speed <= speed_limit:
        print("No fine")
    else:
        excess_speed = speed - speed_limit
        if excess_speed <= 10:
            fine = 50
        elif excess_speed <= 20:
            fine = 100
        else:
            fine = 200
        print(f"Fine: ${fine}")

calculate_speeding_fine()

# 68. Write a program to calculate body fat percentage based on input parameters.
def calculate_body_fat():
    gender = input("Enter gender (M/F): ").upper()
    age = int(input("Enter age: "))
    weight = float(input("Enter weight in kg: "))
    height = float(input("Enter height in cm: "))
    waist = float(input("Enter waist circumference in cm: "))
    neck = float(input("Enter neck circumference in cm: "))
    if gender == 'M':
        body_fat = 495 / (1.0324 - 0.19077 * (waist - neck) / height + 0.15456 * height) - 450
    else:
        hip = float(input("Enter hip circumference in cm: "))
        body_fat = 495 / (1.29579 - 0.35004 * (waist + hip - neck) / height + 0.22100 * height) - 450
    print(f"Body fat percentage: {body_fat:.2f}%")

calculate_body_fat()

# 69. Write a program to calculate the total cost of items in a shopping cart.
def shopping_cart():
    n = int(input("Enter number of items: "))
    total_cost = 0
    for _ in range(n):
        price = float(input("Enter price of item: "))
        quantity = int(input("Enter quantity of item: "))
        total_cost += price * quantity
    print(f"Total cost: ${total_cost}")

shopping_cart()

# 70. Write a program to calculate pay based on different work shifts.
def calculate_pay():
    shift = input("Enter shift (morning/afternoon/night): ").lower()
    hours = float(input("Enter number of hours worked: "))
    if shift == 'morning':
        rate = 10
    elif shift == 'afternoon':
        rate = 15
    elif shift == 'night':
        rate = 20
    else:
        print("Invalid shift")
        return
    pay = rate * hours
    print(f"Total pay: ${pay}")

calculate_pay()

# 71. Write a program to print Pascal’s triangle.
def pascals_triangle():
    rows = int(input("Enter number of rows: "))
    for i in range(rows):
        for j in range(rows - i - 1):
            print(" ", end="")
        num = 1
        for j in range(i + 1):
            print(num, end=" ")
            num = num * (i - j) // (j + 1)
        print()

pascals_triangle()

# Method 2
def generate_pascals_triangle(n):
    triangle = []
    for i in range(n):
        row = [1] * (i + 1)
        for j in range(1, i):
            row[j] = triangle[i - 1][j - 1] + triangle[i - 1][j]
        triangle.append(row)
    return triangle

def print_pascals_triangle(triangle):
    for row in triangle:
        print(' '.join(map(str, row)).center(2*n - 1))

n = int(input("Enter number of rows: "))
triangle = generate_pascals_triangle(n)
print_pascals_triangle(triangle)


# 72. Write a program to find the sum of squares of the first N natural numbers.
def sum_of_squares():
    n = int(input("Enter the number of terms: "))
    sum_squares = sum(i**2 for i in range(1, n + 1))
    print(f"Sum of squares: {sum_squares}")

sum_of_squares()

# 73. Write a program to find the sum of cubes of the first N natural numbers.
def sum_of_cubes():
    n = int(input("Enter the number of terms: "))
    sum_cubes = sum(i**3 for i in range(1, n + 1))
    print(f"Sum of cubes: {sum_cubes}")

sum_of_cubes()

# 74. Write a program to find all perfect numbers within a given range.
def find_perfect_numbers():
    start = int(input("Enter start of range: "))
    end = int(input("Enter end of range: "))
    perfect_numbers = []
    for num in range(start, end + 1):
        if num > 1:
            sum_divisors = sum(i for i in range(1, num) if num % i == 0)
            if sum_divisors == num:
                perfect_numbers.append(num)
    print("Perfect numbers:", perfect_numbers)

find_perfect_numbers()

# 75. Write a program to count the frequency of each digit in a number.
def digit_frequency():
    number = input("Enter a number: ")
    frequency = {}
    for digit in number:
        if digit.isdigit():
            frequency[digit] = frequency.get(digit, 0) + 1
    print("Digit frequency:", frequency)

digit_frequency()

from collections import Counter

def digit_frequency():
    number = input("Enter a number: ")
    digits = [digit for digit in number if digit.isdigit()]
    frequency = Counter(digits)
    print("Digit frequency:", dict(frequency))

digit_frequency()

# 76. Write a program to convert a binary number to a decimal number.
def binary_to_decimal():
    binary = input("Enter a binary number: ")
    decimal = int(binary, 2)
    print(f"Decimal: {decimal}")

binary_to_decimal()

# 77. Write a program to convert a decimal number to a binary number.
def decimal_to_binary():
    decimal = int(input("Enter a decimal number: "))
    binary = bin(decimal)[2:]
    print(f"Binary: {binary}")

decimal_to_binary()

# 78. Write a program to print a number pattern.
def number_pattern():
    rows = int(input("Enter number of rows: "))
    for i in range(1, rows + 1):
        for j in range(1, i + 1):
            print(j, end=" ")
        print()

number_pattern()

# 79. Write a program to print various star patterns.
def star_patterns():
    rows = int(input("Enter number of rows: "))

    # Right triangle
    print("Right triangle pattern:")
    for i in range(1, rows + 1):
        print('*' * i)
    print()

    # Inverted triangle
    print("Inverted triangle pattern:")
    for i in range(rows, 0, -1):
        print('*' * i)
    print()

    # Pyramid
    print("Pyramid pattern:")
    for i in range(1, rows + 1):
        print(' ' * (rows - i) + '*' * (2 * i - 1))
    print()

    # Diamond
    print("Diamond pattern:")
    for i in range(1, rows + 1):
        print(' ' * (rows - i) + '*' * (2 * i - 1))
    for i in range(rows - 1, 0, -1):
        print(' ' * (rows - i) + '*' * (2 * i - 1))
    print()

star_patterns()

# 80. Write a program to create simple ASCII art using loops.
def ascii_art():
    height = 5
    width = 5
    for i in range(height):
        for j in range(width):
            print("*", end=" ")
        print()

ascii_art()

# 81. Write a program to count the frequency of each element in a list.
def element_frequency():
    lst = list(map(int, input("Enter list elements separated by space: ").split()))
    frequency = {}
    for item in lst:
        frequency[item] = frequency.get(item, 0) + 1
    print("Element frequency:", frequency)

element_frequency()

# 82. Write a program to rotate elements of a list to the left or right.
def rotate_list():
    lst = list(map(int, input("Enter list elements separated by space: ").split()))
    direction = input("Rotate left or right? (L/R): ").upper()
    positions = int(input("Enter number of positions to rotate: "))

    if direction == 'L':
        rotated_list = lst[positions:] + lst[:positions]
    else:
        rotated_list = lst[-positions:] + lst[:-positions]

    print("Rotated list:", rotated_list)

rotate_list()

# 83. Write a program to check if two strings are anagrams.
def are_anagrams():
    str1 = input("Enter first string: ")
    str2 = input("Enter second string: ")
    if sorted(str1) == sorted(str2):
        print("The strings are anagrams.")
    else:
        print("The strings are not anagrams.")

are_anagrams()

# 84. Write a program to check if a string is a substring of another string.
def is_substring():
    str1 = input("Enter the main string: ")
    str2 = input("Enter the substring: ")
    if str2 in str1:
        print("The string is a substring.")
    else:
        print("The string is not a substring.")

is_substring()

# 85. Write a program to invert keys and values in a dictionary.
def invert_dict():
    d = {"a": 1, "b": 2, "c": 3}
    inverted_dict = {v: k for k, v in d.items()}
    print("Inverted dictionary:", inverted_dict)

invert_dict()

# 86. Write a program to demonstrate packing and unpacking of tuples.
def tuple_packing_unpacking():
    # Packing
    t = (1, 2, 3, 4)
    print("Packed tuple:", t)

    # Unpacking
    a, b, c, d = t
    print("Unpacked values:", a, b, c, d)

tuple_packing_unpacking()

# 87. Write a program to generate a random number within a specified range.
import random

def random_number():
    start = int(input("Enter start of range: "))
    end = int(input("Enter end of range: "))
    rand_num = random.randint(start, end)
    print(f"Random number between {start} and {end}: {rand_num}")

random_number()

# 88. Write a program to find the most frequent element in a list.
def most_frequent_element():
    lst = list(map(int, input("Enter list elements separated by space: ").split()))
    frequency = {}
    for item in lst:
        frequency[item] = frequency.get(item, 0) + 1
    most_frequent = max(frequency, key=frequency.get)
    print("Most frequent element:", most_frequent)

most_frequent_element()

# 89. Write a program to find the least frequent element in a list.
def least_frequent_element():
    lst = list(map(int, input("Enter list elements separated by space: ").split()))
    frequency = {}
    for item in lst:
        frequency[item] = frequency.get(item, 0) + 1
    least_frequent = min(frequency, key=frequency.get)
    print("Least frequent element:", least_frequent)

least_frequent_element()

# 90. Write a program to count the number of occurrences of each word in a string.
def word_count():
    text = input("Enter a string: ")
    words = text.split()
    frequency = {}
    for word in words:
        frequency[word] = frequency.get(word, 0) + 1
    print("Word frequency:", frequency)

word_count()

# 91. Write a program to remove punctuation from a string.
import string

def remove_punctuation():
    text = input("Enter a string: ")
    cleaned_text = ''.join(char for char in text if char not in string.punctuation)
    print("String without punctuation:", cleaned_text)

remove_punctuation()

# 92. Write a program to find the common elements in three lists.
def common_elements_in_three_lists():
    list1 = list(map(int, input("Enter elements of first list separated by space: ").split()))
    list2 = list(map(int, input("Enter elements of second list separated by space: ").split()))
    list3 = list(map(int, input("Enter elements of third list separated by space: ").split()))
    common_elements = list(set(list1) & set(list2) & set(list3))
    print("Common elements:", common_elements)

common_elements_in_three_lists()

# 93. Write a program to find the uncommon elements in two lists.
def uncommon_elements():
    list1 = list(map(int, input("Enter elements of first list separated by space: ").split()))
    list2 = list(map(int, input("Enter elements of second list separated by space: ").split()))
    set1, set2 = set(list1), set(list2)
    uncommon_elements = list(set1 ^ set2)
    print("Uncommon elements:", uncommon_elements)

uncommon_elements()

# 94. Write a program to remove all occurrences of a specified element from a list.
def remove_occurrences():
    lst = list(map(int, input("Enter list elements separated by space: ").split()))
    element = int(input("Enter element to remove: "))
    updated_list = [item for item in lst if item != element]
    print("Updated list:", updated_list)

remove_occurrences()

# 95. Write a program to find the sum of elements in a dictionary.
def sum_of_dict_values():
    d = {'a': 100, 'b': 200, 'c': 300}
    total_sum = sum(d.values())
    print("Sum of dictionary values:", total_sum)

sum_of_dict_values()

# 96. Write a program to find the maximum value in a dictionary.
def max_dict_value():
    d = {'a': 100, 'b': 200, 'c': 300}
    max_value = max(d.values())
    print("Maximum value in the dictionary:", max_value)

max_dict_value()

# 97. Write a program to find the minimum value in a dictionary.
def min_dict_value():
    d = {'a': 100, 'b': 200, 'c': 300}
    min_value = min(d.values())
    print("Minimum value in the dictionary:", min_value)

min_dict_value()

# 98. Write a program to flatten a list of lists.
def flatten_nested_list():
    nested_list = [[1, 2, [3, 4]], [5, 6], [7, [8, 9]]]

    def flatten(lst):
        flat_list = []
        for item in lst:
            if isinstance(item, list):
                flat_list.extend(flatten(item))
            else:
                flat_list.append(item)
        return flat_list

    flat_list = flatten(nested_list)
    print("Flattened list:", flat_list)

flatten_nested_list()

# 99. Write a program to generate all permutations of a list.
import itertools

def generate_permutations():
    lst = list(map(int, input("Enter list elements separated by space: ").split()))
    permutations = list(itertools.permutations(lst))
    print("All permutations of the list:")
    for p in permutations:
        print(p)

generate_permutations()

# Solution 2
def permute(lst):
    if len(lst) == 0:
        return []
    if len(lst) == 1:
        return [lst]

    result = []
    for i in range(len(lst)):
        current = lst[i]
        remaining_list = lst[:i] + lst[i+1:]
        for p in permute(remaining_list):
            result.append([current] + p)
    return result

def generate_permutations():
    lst = list(map(int, input("Enter list elements separated by space: ").split()))
    permutations = permute(lst)
    print("All permutations of the list:")
    for p in permutations:
        print(p)

generate_permutations()


# 100. Write a program to find the longest word in a string.
def longest_word():
    sentence = input("Enter a sentence: ")
    words = sentence.split()
    longest = max(words, key=len)
    print("Longest word:", longest)

longest_word()
# Out:
# Enter list elements separated by space: 1 3 2 6
# All permutations of the list:
# [1, 3, 2, 6]
# [1, 3, 6, 2]
# [1, 2, 3, 6]
# [1, 2, 6, 3]
# [1, 6, 3, 2]
# [1, 6, 2, 3]
# [3, 1, 2, 6]
# [3, 1, 6, 2]
# [3, 2, 1, 6]
# [3, 2, 6, 1]
# [3, 6, 1, 2]
# [3, 6, 2, 1]
# [2, 1, 3, 6]
# [2, 1, 6, 3]
# [2, 3, 1, 6]
# [2, 3, 6, 1]
# [2, 6, 1, 3]
# [2, 6, 3, 1]
# [6, 1, 3, 2]
# [6, 1, 2, 3]
# [6, 3, 1, 2]
# [6, 3, 2, 1]
# [6, 2, 1, 3]
# [6, 2, 3, 1]
